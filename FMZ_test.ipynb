# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
price_usdt = pd.read_csv('https://www.fmz.com/upload/asset/20227de6c1d10cb9dd1.csv ', index_col = 0)
price_usdt.index = pd.to_datetime(price_usdt.index)

# %%
BTC_price = price_usdt['BTC']
BTC_price.plot(figsize=(18,6),grid = True)

# %%
import talib as TA

# %%
 macd = TA.MACD(BTC_price, 12, 26, 9)

# %%
DIF.columns=['a', 'b']

# %%
DIF.head()
# Out:
# 0
# 2020-02-05 16:00:00   NaN
# 2020-02-05 17:00:00   NaN
# 2020-02-05 18:00:00   NaN
# 2020-02-05 19:00:00   NaN
# 2020-02-05 20:00:00   NaN
# dtype: float64

# %%
class TripleNet(object):
    def __init__(self, pd_price, leverage=20, commission=0.00005,  initial_balance=10000):
        self.pd_price = pd_price #待回测的价格
        self.initial_balance = initial_balance #初始的资产
        self.commission = commission #手续费
        self.leverage = leverage #杠杆
        self.trading_log = pd.DataFrame(columns=['margin','total','leverage','realised_profit','unrealised_profit']) #记录交易
        self.account = {'USDT':{'realised_profit':0, 'margin':0, 'unrealised_profit':0, 'total':initial_balance, 'leverage':0}
                        'BTC': self.account[symbol] = {'amount':0, 'hold_price':0, 'value':0, 'price':0, 'realised_profit':0, 'margin':0, 'unrealised_profit':0}账户信息
        self.account[symbol] = {'amount':0, 'hold_price':0, 'value':0, 'price':0, 'realised_profit':0, 'margin':0, 'unrealised_profit':0}

# %%
"""
margin: 保证金
"""
# Out:
# '\nmargin: 保证金\n'

# %%
result = pd.concat([BTC_price, DIF], axis=1)

# %%
result.head()
# Out:
#                          BTC  DIF_value
# 0
# 2020-02-05 16:00:00  9578.31        NaN
# 2020-02-05 17:00:00  9575.89        NaN
# 2020-02-05 18:00:00  9696.00        NaN
# 2020-02-05 19:00:00  9681.32        NaN
# 2020-02-05 20:00:00  9692.01        NaN

# %%
result.columns = ['BTC', 'DIF_value']

# %%
DEA = pd.Series(list(macd[1]))
DEA.index = _index

# %%
MACD = pd.Series(list(macd[2]))
MACD.index = _index

# %%
res = pd.concat([BTC_price, DIF, DEA, MACD], axis=1)
res.columns = ["BTC_price", "DIF_value", "DEA_value", "MACD_value"]

# %%
res.head()
# Out:
#                      BTC_price  DIF_value  DEA_value  MACD_value
# 0
# 2020-02-05 16:00:00    9578.31        NaN        NaN         NaN
# 2020-02-05 17:00:00    9575.89        NaN        NaN         NaN
# 2020-02-05 18:00:00    9696.00        NaN        NaN         NaN
# 2020-02-05 19:00:00    9681.32        NaN        NaN         NaN
# 2020-02-05 20:00:00    9692.01        NaN        NaN         NaN

# %%
res_norm = res / res.fillna(method='bfill').iloc[0,]
res_norm.plot(figsize=(16,6),grid = True,legend=True)
